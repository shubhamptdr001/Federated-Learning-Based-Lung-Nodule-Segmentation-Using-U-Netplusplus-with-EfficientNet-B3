# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Install MONAI and other libraries if not already present
# !pip install -q monai segmentation-models-pytorch albumentations
# Out:
# Mounted at /content/drive
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 36.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 17.0 MB/s eta 0:00:00

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
import cv2
import random
import copy
import matplotlib.pyplot as plt
from tqdm import tqdm

from monai.losses import DiceFocalLoss
from monai.metrics import DiceMetric, MeanIoU
from monai.transforms import (
    Compose, RandRotated, RandFlipd, RandZoomd, RandAffined,
    RandGaussianNoised, RandAdjustContrastd, ToTensord
)
import segmentation_models_pytorch as smp

seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
CT_DIR = '/content/drive/MyDrive/Minor-Project under DevraniMam/Faderated_Learning_Based_Lung_Nodule_Detection/LUNA16_segmentation_data/ct'
MASK_DIR = '/content/drive/MyDrive/Minor-Project under DevraniMam/Faderated_Learning_Based_Lung_Nodule_Detection/LUNA16_segmentation_data/mask'

ct_files = sorted([f for f in os.listdir(CT_DIR) if f.endswith('.png')])
mask_files = sorted([f for f in os.listdir(MASK_DIR) if f.endswith('.png')])

assert len(ct_files) == len(mask_files), "CT and mask counts mismatch!"
print(f"Total images: {len(ct_files)}")

ct_paths = [os.path.join(CT_DIR, f) for f in ct_files]
mask_paths = [os.path.join(MASK_DIR, f) for f in mask_files]
# Out:
# Total images: 523

# %%
class LungNoduleDataset(Dataset):
    def __init__(self, ct_paths, mask_paths, transform=None):
        self.ct_paths = ct_paths
        self.mask_paths = mask_paths
        self.transform = transform

    def __len__(self):
        return len(self.ct_paths)

    def __getitem__(self, idx):
        img = cv2.imread(self.ct_paths[idx], cv2.IMREAD_GRAYSCALE)
        mask = cv2.imread(self.mask_paths[idx], cv2.IMREAD_GRAYSCALE)

        img = cv2.resize(img, (256, 256))
        mask = cv2.resize(mask, (256, 256), interpolation=cv2.INTER_NEAREST)

        img = img.astype(np.float32) / 255.0
        mask = (mask > 127).astype(np.float32)

        img = np.expand_dims(img, axis=0)
        mask = np.expand_dims(mask, axis=0)

        data = {'image': img, 'mask': mask}
        if self.transform:
            data = self.transform(data)
        return data['image'], data['mask']

train_transforms = Compose([
    RandRotated(keys=['image','mask'], range_x=0.3, prob=0.5, mode=['bilinear','nearest']),
    RandFlipd(keys=['image','mask'], spatial_axis=0, prob=0.5),
    RandFlipd(keys=['image','mask'], spatial_axis=1, prob=0.5),
    RandZoomd(keys=['image','mask'], min_zoom=0.8, max_zoom=1.2, prob=0.5, mode=['bilinear','nearest']),
    RandAffined(keys=['image','mask'], rotate_range=0.2, translate_range=0.1, scale_range=0.1, prob=0.5, mode=['bilinear','nearest']),
    RandGaussianNoised(keys=['image'], std=0.01, prob=0.3),
    RandAdjustContrastd(keys=['image'], gamma=(0.8,1.2), prob=0.3),
    ToTensord(keys=['image','mask'], dtype=torch.float32),
])

val_transforms = Compose([
    ToTensord(keys=['image','mask'], dtype=torch.float32),
])

# %%
def split_clients(ct_paths, mask_paths, num_clients=5, val_ratio=0.15, test_ratio=0.15):
    indices = np.arange(len(ct_paths))
    np.random.shuffle(indices)
    client_indices = np.array_split(indices, num_clients)

    clients = []
    for client_idx in client_indices:
        train_idx, temp_idx = train_test_split(client_idx, test_size=(val_ratio+test_ratio), random_state=42)
        val_idx, test_idx = train_test_split(temp_idx, test_size=test_ratio/(val_ratio+test_ratio), random_state=42)
        clients.append({
            'train': train_idx.tolist(),
            'val': val_idx.tolist(),
            'test': test_idx.tolist()
        })
    return clients

clients = split_clients(ct_paths, mask_paths, num_clients=5)
print("Client data sizes:")
for i, c in enumerate(clients):
    print(f"Client {i}: train={len(c['train'])}, val={len(c['val'])}, test={len(c['test'])}")
# Out:
# Client data sizes:
# Client 0: train=73, val=16, test=16
# Client 1: train=73, val=16, test=16
# Client 2: train=73, val=16, test=16
# Client 3: train=72, val=16, test=16
# Client 4: train=72, val=16, test=16

# %%
batch_size = 8
num_workers = 2

client_dataloaders = []
for client in clients:
    train_ds = LungNoduleDataset([ct_paths[i] for i in client['train']],
                                 [mask_paths[i] for i in client['train']],
                                 transform=train_transforms)
    val_ds = LungNoduleDataset([ct_paths[i] for i in client['val']],
                               [mask_paths[i] for i in client['val']],
                               transform=val_transforms)
    test_ds = LungNoduleDataset([ct_paths[i] for i in client['test']],
                                [mask_paths[i] for i in client['test']],
                                transform=val_transforms)

    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=num_workers)
    val_loader = DataLoader(val_ds, batch_size=batch_size, shuffle=False, num_workers=num_workers)
    test_loader = DataLoader(test_ds, batch_size=batch_size, shuffle=False, num_workers=num_workers)

    client_dataloaders.append({
        'train': train_loader,
        'val': val_loader,
        'test': test_loader
    })

# %%
def build_model():
    model = smp.UnetPlusPlus(
        encoder_name="efficientnet-b3",
        encoder_weights="imagenet",
        in_channels=1,
        classes=1,
    )
    return model

model = build_model().to(device)
print(f"Model parameters: {sum(p.numel() for p in model.parameters())/1e6:.2f}M")
model.summary()   // new add
# Out:
# config.json:   0%|          | 0.00/106 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 49.3MB
# model.safetensors: downloading bytes:           |  0.00B
# Model parameters: 13.62M

# %%
loss_fn = DiceFocalLoss(sigmoid=True, squared_pred=True, reduction='mean')
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-5)

def compute_dice(pred, target):
    pred = (torch.sigmoid(pred) > 0.5).float()
    intersection = (pred * target).sum()
    return (2. * intersection + 1e-6) / (pred.sum() + target.sum() + 1e-6)

def compute_iou(pred, target):
    pred = (torch.sigmoid(pred) > 0.5).float()
    intersection = (pred * target).sum()
    union = pred.sum() + target.sum() - intersection
    return (intersection + 1e-6) / (union + 1e-6)

# %%
def client_update(global_weights, train_loader, local_epochs=2, lr=1e-4, verbose=True):
    model = build_model().to(device)
    model.load_state_dict(global_weights)
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-5)

    model.train()
    epoch_losses = []
    epoch_dices = []

    for epoch in range(local_epochs):
        running_loss = 0.0
        running_dice = 0.0
        num_batches = 0

        for imgs, masks in train_loader:
            imgs, masks = imgs.to(device), masks.to(device)
            logits = model(imgs)
            loss = loss_fn(logits, masks)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            dice = compute_dice(logits.detach(), masks)
            running_loss += loss.item()
            running_dice += dice.item()
            num_batches += 1

        avg_loss = running_loss / num_batches
        avg_dice = running_dice / num_batches
        epoch_losses.append(avg_loss)
        epoch_dices.append(avg_dice)

        if verbose:
            print(f"    Local Epoch {epoch+1}/{local_epochs} - Loss: {avg_loss:.4f}, Dice: {avg_dice:.4f}")

    return model.state_dict(), len(train_loader.dataset), epoch_losses, epoch_dices

def aggregate_weights(client_weights, total_samples):
    new_weights = {}
    for key in client_weights[0][0].keys():
        weighted_sum = torch.zeros_like(client_weights[0][0][key])
        for w, n in client_weights:
            weighted_sum += w[key] * n
        new_weights[key] = weighted_sum / total_samples
    return new_weights

def evaluate(weights, dataloader):
    model = build_model().to(device)
    model.load_state_dict(weights)
    model.eval()
    dice_scores = []
    iou_scores = []
    with torch.no_grad():
        for imgs, masks in dataloader:
            imgs, masks = imgs.to(device), masks.to(device)
            logits = model(imgs)
            dice = compute_dice(logits, masks)
            iou = compute_iou(logits, masks)
            dice_scores.append(dice.item())
            iou_scores.append(iou.item())
    return np.mean(dice_scores), np.mean(iou_scores)

# %%
global_weights = build_model().state_dict()

num_rounds = 50
local_epochs = 2
local_lr = 1e-4

results = {'round': [], 'avg_val_dice': [], 'avg_test_dice': [], 'avg_test_iou': []}

for round in range(num_rounds):
    print(f"--- Federated Round {round+1}/{num_rounds} ---")
    client_weights = []
    total_samples = 0

    for i, client in enumerate(client_dataloaders):
        print(f"  Client {i} training...")
        w, n, _, _ = client_update(global_weights, client['train'],
                                   local_epochs=local_epochs, lr=local_lr, verbose=True)
        client_weights.append((w, n))
        total_samples += n

    global_weights = aggregate_weights(client_weights, total_samples)

    if (round+1) % 5 == 0 or round == num_rounds-1:
        val_dices = []
        test_dices = []
        test_ious = []
        for i, client in enumerate(client_dataloaders):
            val_dice, _ = evaluate(global_weights, client['val'])
            test_dice, test_iou = evaluate(global_weights, client['test'])
            val_dices.append(val_dice)
            test_dices.append(test_dice)
            test_ious.append(test_iou)
        avg_val_dice = np.mean(val_dices)
        avg_test_dice = np.mean(test_dices)
        avg_test_iou = np.mean(test_ious)
        results['round'].append(round+1)
        results['avg_val_dice'].append(avg_val_dice)
        results['avg_test_dice'].append(avg_test_dice)
        results['avg_test_iou'].append(avg_test_iou)
        print(f"  Round {round+1}: Avg Val Dice={avg_val_dice:.4f}, Avg Test Dice={avg_test_dice:.4f}, Avg Test IoU={avg_test_iou:.4f}")
# Out:
# --- Federated Round 1/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 1.5344, Dice: 0.0019
#     Local Epoch 2/2 - Loss: 1.4183, Dice: 0.0015
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 1.5342, Dice: 0.0019
#     Local Epoch 2/2 - Loss: 1.4191, Dice: 0.0018
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 1.5369, Dice: 0.0019
#     Local Epoch 2/2 - Loss: 1.4211, Dice: 0.0016
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 1.5400, Dice: 0.0019
#     Local Epoch 2/2 - Loss: 1.4285, Dice: 0.0017
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 1.5405, Dice: 0.0021
#     Local Epoch 2/2 - Loss: 1.4313, Dice: 0.0018
# --- Federated Round 2/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 1.3305, Dice: 0.0016
#     Local Epoch 2/2 - Loss: 1.2426, Dice: 0.0017
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 1.3230, Dice: 0.0023
#     Local Epoch 2/2 - Loss: 1.2430, Dice: 0.0017
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 1.3282, Dice: 0.0016
#     Local Epoch 2/2 - Loss: 1.2380, Dice: 0.0021
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 1.3333, Dice: 0.0015
#     Local Epoch 2/2 - Loss: 1.2505, Dice: 0.0016
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 1.3380, Dice: 0.0017
#     Local Epoch 2/2 - Loss: 1.2524, Dice: 0.0020
# --- Federated Round 3/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 1.1817, Dice: 0.0023
#     Local Epoch 2/2 - Loss: 1.1440, Dice: 0.0023
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 1.1833, Dice: 0.0020
#     Local Epoch 2/2 - Loss: 1.1436, Dice: 0.0020
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 1.1814, Dice: 0.0023
#     Local Epoch 2/2 - Loss: 1.1484, Dice: 0.0027
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 1.1813, Dice: 0.0023
#     Local Epoch 2/2 - Loss: 1.1485, Dice: 0.0023
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 1.1855, Dice: 0.0025
#     Local Epoch 2/2 - Loss: 1.1472, Dice: 0.0027
# --- Federated Round 4/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 1.1200, Dice: 0.0026
#     Local Epoch 2/2 - Loss: 1.0943, Dice: 0.0028
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 1.1171, Dice: 0.0021
#     Local Epoch 2/2 - Loss: 1.0934, Dice: 0.0027
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 1.1196, Dice: 0.0029
#     Local Epoch 2/2 - Loss: 1.0963, Dice: 0.0028
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 1.1182, Dice: 0.0026
#     Local Epoch 2/2 - Loss: 1.0966, Dice: 0.0032
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 1.1176, Dice: 0.0024
#     Local Epoch 2/2 - Loss: 1.0952, Dice: 0.0030
# --- Federated Round 5/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 1.0862, Dice: 0.0043
#     Local Epoch 2/2 - Loss: 1.0687, Dice: 0.0045
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 1.0795, Dice: 0.0029
#     Local Epoch 2/2 - Loss: 1.0660, Dice: 0.0059
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 1.0761, Dice: 0.0041
#     Local Epoch 2/2 - Loss: 1.0681, Dice: 0.0053
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 1.0783, Dice: 0.0044
#     Local Epoch 2/2 - Loss: 1.0644, Dice: 0.0062
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 1.0794, Dice: 0.0034
#     Local Epoch 2/2 - Loss: 1.0651, Dice: 0.0046
#   Round 5: Avg Val Dice=0.0001, Avg Test Dice=0.0001, Avg Test IoU=0.0000
# --- Federated Round 6/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 1.0544, Dice: 0.0070
#     Local Epoch 2/2 - Loss: 1.0510, Dice: 0.0180
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 1.0578, Dice: 0.0080
#     Local Epoch 2/2 - Loss: 1.0462, Dice: 0.0125
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 1.0561, Dice: 0.0065
#     Local Epoch 2/2 - Loss: 1.0467, Dice: 0.0091
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 1.0543, Dice: 0.0091
#     Local Epoch 2/2 - Loss: 1.0455, Dice: 0.0162
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 1.0543, Dice: 0.0078
#     Local Epoch 2/2 - Loss: 1.0454, Dice: 0.0214
# --- Federated Round 7/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 1.0396, Dice: 0.0207
#     Local Epoch 2/2 - Loss: 1.0326, Dice: 0.0340
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 1.0424, Dice: 0.0183
#     Local Epoch 2/2 - Loss: 1.0313, Dice: 0.0288
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 1.0432, Dice: 0.0151
#     Local Epoch 2/2 - Loss: 1.0318, Dice: 0.0197
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 1.0369, Dice: 0.0267
#     Local Epoch 2/2 - Loss: 1.0335, Dice: 0.0307
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 1.0362, Dice: 0.0247
#     Local Epoch 2/2 - Loss: 1.0305, Dice: 0.0400
# --- Federated Round 8/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 1.0265, Dice: 0.0753
#     Local Epoch 2/2 - Loss: 1.0258, Dice: 0.1464
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 1.0285, Dice: 0.0489
#     Local Epoch 2/2 - Loss: 1.0232, Dice: 0.1180
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 1.0285, Dice: 0.0538
#     Local Epoch 2/2 - Loss: 1.0252, Dice: 0.1191
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 1.0262, Dice: 0.0765
#     Local Epoch 2/2 - Loss: 1.0219, Dice: 0.1306
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 1.0264, Dice: 0.0522
#     Local Epoch 2/2 - Loss: 1.0217, Dice: 0.1669
# --- Federated Round 9/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 1.0193, Dice: 0.3163
#     Local Epoch 2/2 - Loss: 1.0148, Dice: 0.4021
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 1.0199, Dice: 0.1475
#     Local Epoch 2/2 - Loss: 1.0199, Dice: 0.2983
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 1.0181, Dice: 0.2747
#     Local Epoch 2/2 - Loss: 1.0172, Dice: 0.3274
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 1.0175, Dice: 0.2923
#     Local Epoch 2/2 - Loss: 1.0137, Dice: 0.3812
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 1.0170, Dice: 0.2943
#     Local Epoch 2/2 - Loss: 1.0136, Dice: 0.4379
# --- Federated Round 10/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 1.0125, Dice: 0.4154
#     Local Epoch 2/2 - Loss: 1.0079, Dice: 0.4456
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 1.0127, Dice: 0.3811
#     Local Epoch 2/2 - Loss: 1.0088, Dice: 0.4183
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 1.0123, Dice: 0.3751
#     Local Epoch 2/2 - Loss: 1.0082, Dice: 0.4005
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 1.0102, Dice: 0.4807
#     Local Epoch 2/2 - Loss: 1.0077, Dice: 0.3902
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 1.0097, Dice: 0.5003
#     Local Epoch 2/2 - Loss: 1.0062, Dice: 0.4798
#   Round 10: Avg Val Dice=0.4284, Avg Test Dice=0.4590, Avg Test IoU=0.3144
# --- Federated Round 11/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 1.0037, Dice: 0.4654
#     Local Epoch 2/2 - Loss: 0.9980, Dice: 0.4626
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 1.0056, Dice: 0.3699
#     Local Epoch 2/2 - Loss: 1.0026, Dice: 0.3809
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 1.0063, Dice: 0.3828
#     Local Epoch 2/2 - Loss: 0.9957, Dice: 0.4774
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 1.0046, Dice: 0.4601
#     Local Epoch 2/2 - Loss: 0.9993, Dice: 0.4577
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 1.0014, Dice: 0.4514
#     Local Epoch 2/2 - Loss: 0.9972, Dice: 0.4235
# --- Federated Round 12/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.9968, Dice: 0.3996
#     Local Epoch 2/2 - Loss: 0.9933, Dice: 0.3152
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.9990, Dice: 0.3745
#     Local Epoch 2/2 - Loss: 0.9955, Dice: 0.3056
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 1.0029, Dice: 0.3242
#     Local Epoch 2/2 - Loss: 0.9920, Dice: 0.3851
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.9951, Dice: 0.3495
#     Local Epoch 2/2 - Loss: 0.9917, Dice: 0.4170
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.9934, Dice: 0.4011
#     Local Epoch 2/2 - Loss: 0.9917, Dice: 0.3746
# --- Federated Round 13/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.9887, Dice: 0.3600
#     Local Epoch 2/2 - Loss: 0.9803, Dice: 0.3699
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.9897, Dice: 0.3436
#     Local Epoch 2/2 - Loss: 0.9874, Dice: 0.3890
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.9885, Dice: 0.3686
#     Local Epoch 2/2 - Loss: 0.9845, Dice: 0.3594
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.9916, Dice: 0.3314
#     Local Epoch 2/2 - Loss: 0.9842, Dice: 0.4086
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.9859, Dice: 0.4039
#     Local Epoch 2/2 - Loss: 0.9834, Dice: 0.4038
# --- Federated Round 14/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.9743, Dice: 0.3849
#     Local Epoch 2/2 - Loss: 0.9757, Dice: 0.4581
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.9837, Dice: 0.3404
#     Local Epoch 2/2 - Loss: 0.9820, Dice: 0.3765
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.9813, Dice: 0.3667
#     Local Epoch 2/2 - Loss: 0.9727, Dice: 0.4120
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.9805, Dice: 0.3651
#     Local Epoch 2/2 - Loss: 0.9768, Dice: 0.4312
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.9754, Dice: 0.4752
#     Local Epoch 2/2 - Loss: 0.9724, Dice: 0.4090
# --- Federated Round 15/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.9737, Dice: 0.3847
#     Local Epoch 2/2 - Loss: 0.9683, Dice: 0.3541
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.9705, Dice: 0.3976
#     Local Epoch 2/2 - Loss: 0.9748, Dice: 0.3903
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.9758, Dice: 0.3861
#     Local Epoch 2/2 - Loss: 0.9699, Dice: 0.3635
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.9721, Dice: 0.4563
#     Local Epoch 2/2 - Loss: 0.9672, Dice: 0.4118
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.9720, Dice: 0.4286
#     Local Epoch 2/2 - Loss: 0.9621, Dice: 0.4561
#   Round 15: Avg Val Dice=0.5784, Avg Test Dice=0.5816, Avg Test IoU=0.4130
# --- Federated Round 16/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.9577, Dice: 0.4392
#     Local Epoch 2/2 - Loss: 0.9599, Dice: 0.4087
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.9697, Dice: 0.3769
#     Local Epoch 2/2 - Loss: 0.9660, Dice: 0.3999
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.9546, Dice: 0.4817
#     Local Epoch 2/2 - Loss: 0.9619, Dice: 0.4759
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.9634, Dice: 0.4598
#     Local Epoch 2/2 - Loss: 0.9578, Dice: 0.4373
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.9605, Dice: 0.4598
#     Local Epoch 2/2 - Loss: 0.9558, Dice: 0.4384
# --- Federated Round 17/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.9577, Dice: 0.4060
#     Local Epoch 2/2 - Loss: 0.9549, Dice: 0.4344
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.9636, Dice: 0.4159
#     Local Epoch 2/2 - Loss: 0.9563, Dice: 0.4285
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.9572, Dice: 0.4465
#     Local Epoch 2/2 - Loss: 0.9439, Dice: 0.4707
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.9548, Dice: 0.4485
#     Local Epoch 2/2 - Loss: 0.9505, Dice: 0.4872
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.9488, Dice: 0.4718
#     Local Epoch 2/2 - Loss: 0.9425, Dice: 0.5033
# --- Federated Round 18/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.9481, Dice: 0.4436
#     Local Epoch 2/2 - Loss: 0.9317, Dice: 0.4897
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.9515, Dice: 0.4291
#     Local Epoch 2/2 - Loss: 0.9470, Dice: 0.4802
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.9503, Dice: 0.4597
#     Local Epoch 2/2 - Loss: 0.9432, Dice: 0.4725
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.9443, Dice: 0.5047
#     Local Epoch 2/2 - Loss: 0.9406, Dice: 0.4633
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.9378, Dice: 0.5074
#     Local Epoch 2/2 - Loss: 0.9350, Dice: 0.5454
# --- Federated Round 19/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.9335, Dice: 0.4533
#     Local Epoch 2/2 - Loss: 0.9326, Dice: 0.4277
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.9367, Dice: 0.4778
#     Local Epoch 2/2 - Loss: 0.9396, Dice: 0.4193
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.9407, Dice: 0.5000
#     Local Epoch 2/2 - Loss: 0.9310, Dice: 0.4932
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.9342, Dice: 0.4897
#     Local Epoch 2/2 - Loss: 0.9269, Dice: 0.4995
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.9249, Dice: 0.5226
#     Local Epoch 2/2 - Loss: 0.9224, Dice: 0.5506
# --- Federated Round 20/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.9152, Dice: 0.5113
#     Local Epoch 2/2 - Loss: 0.9179, Dice: 0.4687
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.9295, Dice: 0.4913
#     Local Epoch 2/2 - Loss: 0.9221, Dice: 0.5132
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.9075, Dice: 0.5649
#     Local Epoch 2/2 - Loss: 0.9177, Dice: 0.4983
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.9186, Dice: 0.5274
#     Local Epoch 2/2 - Loss: 0.9154, Dice: 0.5142
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.9184, Dice: 0.5233
#     Local Epoch 2/2 - Loss: 0.9069, Dice: 0.5789
#   Round 20: Avg Val Dice=0.6289, Avg Test Dice=0.6288, Avg Test IoU=0.4630
# --- Federated Round 21/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.9130, Dice: 0.5360
#     Local Epoch 2/2 - Loss: 0.9094, Dice: 0.4564
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.9213, Dice: 0.4904
#     Local Epoch 2/2 - Loss: 0.9062, Dice: 0.4955
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.9087, Dice: 0.5397
#     Local Epoch 2/2 - Loss: 0.9077, Dice: 0.4995
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.9096, Dice: 0.5741
#     Local Epoch 2/2 - Loss: 0.8973, Dice: 0.5402
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.9022, Dice: 0.5788
#     Local Epoch 2/2 - Loss: 0.8916, Dice: 0.5505
# --- Federated Round 22/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.9014, Dice: 0.5441
#     Local Epoch 2/2 - Loss: 0.8866, Dice: 0.5475
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.8999, Dice: 0.5333
#     Local Epoch 2/2 - Loss: 0.8909, Dice: 0.5509
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.8703, Dice: 0.6023
#     Local Epoch 2/2 - Loss: 0.8887, Dice: 0.5334
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.8904, Dice: 0.5867
#     Local Epoch 2/2 - Loss: 0.8809, Dice: 0.5600
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.8817, Dice: 0.5712
#     Local Epoch 2/2 - Loss: 0.8779, Dice: 0.5933
# --- Federated Round 23/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.8787, Dice: 0.5541
#     Local Epoch 2/2 - Loss: 0.8520, Dice: 0.5975
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.8830, Dice: 0.5437
#     Local Epoch 2/2 - Loss: 0.8857, Dice: 0.4903
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.8852, Dice: 0.5802
#     Local Epoch 2/2 - Loss: 0.8731, Dice: 0.5100
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.8778, Dice: 0.5789
#     Local Epoch 2/2 - Loss: 0.8640, Dice: 0.5379
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.8665, Dice: 0.6316
#     Local Epoch 2/2 - Loss: 0.8492, Dice: 0.6514
# --- Federated Round 24/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.8588, Dice: 0.5952
#     Local Epoch 2/2 - Loss: 0.8514, Dice: 0.5784
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.8726, Dice: 0.5645
#     Local Epoch 2/2 - Loss: 0.8383, Dice: 0.6366
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.8596, Dice: 0.5715
#     Local Epoch 2/2 - Loss: 0.8401, Dice: 0.6535
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.8578, Dice: 0.5864
#     Local Epoch 2/2 - Loss: 0.8453, Dice: 0.6208
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.8382, Dice: 0.6506
#     Local Epoch 2/2 - Loss: 0.8361, Dice: 0.6393
# --- Federated Round 25/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.8361, Dice: 0.6048
#     Local Epoch 2/2 - Loss: 0.7998, Dice: 0.6452
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.8439, Dice: 0.6240
#     Local Epoch 2/2 - Loss: 0.8309, Dice: 0.6738
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.8375, Dice: 0.6263
#     Local Epoch 2/2 - Loss: 0.8209, Dice: 0.6361
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.8350, Dice: 0.6613
#     Local Epoch 2/2 - Loss: 0.8156, Dice: 0.6119
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.8244, Dice: 0.6589
#     Local Epoch 2/2 - Loss: 0.8066, Dice: 0.6339
#   Round 25: Avg Val Dice=0.6913, Avg Test Dice=0.6669, Avg Test IoU=0.5055
# --- Federated Round 26/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.8160, Dice: 0.6030
#     Local Epoch 2/2 - Loss: 0.8093, Dice: 0.6122
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.8243, Dice: 0.5928
#     Local Epoch 2/2 - Loss: 0.8060, Dice: 0.6825
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.8138, Dice: 0.6181
#     Local Epoch 2/2 - Loss: 0.7854, Dice: 0.7003
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.8006, Dice: 0.6486
#     Local Epoch 2/2 - Loss: 0.7921, Dice: 0.6778
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.7902, Dice: 0.6861
#     Local Epoch 2/2 - Loss: 0.7748, Dice: 0.6818
# --- Federated Round 27/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.7967, Dice: 0.5468
#     Local Epoch 2/2 - Loss: 0.7250, Dice: 0.6365
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.7776, Dice: 0.6443
#     Local Epoch 2/2 - Loss: 0.7916, Dice: 0.6725
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.7587, Dice: 0.6785
#     Local Epoch 2/2 - Loss: 0.7514, Dice: 0.6681
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.7754, Dice: 0.6944
#     Local Epoch 2/2 - Loss: 0.7526, Dice: 0.6617
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.7660, Dice: 0.6957
#     Local Epoch 2/2 - Loss: 0.7404, Dice: 0.7197
# --- Federated Round 28/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.7293, Dice: 0.7024
#     Local Epoch 2/2 - Loss: 0.7479, Dice: 0.6330
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.7304, Dice: 0.7037
#     Local Epoch 2/2 - Loss: 0.7045, Dice: 0.6522
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.7383, Dice: 0.6897
#     Local Epoch 2/2 - Loss: 0.7196, Dice: 0.7090
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.7469, Dice: 0.6723
#     Local Epoch 2/2 - Loss: 0.7419, Dice: 0.6738
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.7360, Dice: 0.6976
#     Local Epoch 2/2 - Loss: 0.7185, Dice: 0.7246
# --- Federated Round 29/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.6919, Dice: 0.6908
#     Local Epoch 2/2 - Loss: 0.7084, Dice: 0.6726
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.7303, Dice: 0.6762
#     Local Epoch 2/2 - Loss: 0.7274, Dice: 0.6902
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.7270, Dice: 0.6912
#     Local Epoch 2/2 - Loss: 0.6908, Dice: 0.6805
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.6991, Dice: 0.7135
#     Local Epoch 2/2 - Loss: 0.6814, Dice: 0.7239
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.6968, Dice: 0.7365
#     Local Epoch 2/2 - Loss: 0.6711, Dice: 0.7606
# --- Federated Round 30/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.7034, Dice: 0.6696
#     Local Epoch 2/2 - Loss: 0.6738, Dice: 0.7021
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.7071, Dice: 0.6538
#     Local Epoch 2/2 - Loss: 0.6836, Dice: 0.6949
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.6746, Dice: 0.7272
#     Local Epoch 2/2 - Loss: 0.6551, Dice: 0.6725
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.6630, Dice: 0.7489
#     Local Epoch 2/2 - Loss: 0.6469, Dice: 0.7523
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.6576, Dice: 0.7479
#     Local Epoch 2/2 - Loss: 0.6412, Dice: 0.7648
#   Round 30: Avg Val Dice=0.7778, Avg Test Dice=0.7598, Avg Test IoU=0.6181
# --- Federated Round 31/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.6720, Dice: 0.6816
#     Local Epoch 2/2 - Loss: 0.6503, Dice: 0.6874
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.6491, Dice: 0.7512
#     Local Epoch 2/2 - Loss: 0.6341, Dice: 0.7526
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.6358, Dice: 0.7249
#     Local Epoch 2/2 - Loss: 0.6196, Dice: 0.6965
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.6440, Dice: 0.7054
#     Local Epoch 2/2 - Loss: 0.6105, Dice: 0.7111
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.6181, Dice: 0.7759
#     Local Epoch 2/2 - Loss: 0.5967, Dice: 0.7897
# --- Federated Round 32/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.6167, Dice: 0.7006
#     Local Epoch 2/2 - Loss: 0.6149, Dice: 0.7082
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.6307, Dice: 0.7121
#     Local Epoch 2/2 - Loss: 0.6004, Dice: 0.7405
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.6126, Dice: 0.7080
#     Local Epoch 2/2 - Loss: 0.5944, Dice: 0.7593
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.6088, Dice: 0.7165
#     Local Epoch 2/2 - Loss: 0.5661, Dice: 0.7657
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.5740, Dice: 0.7645
#     Local Epoch 2/2 - Loss: 0.5644, Dice: 0.7516
# --- Federated Round 33/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.5477, Dice: 0.7532
#     Local Epoch 2/2 - Loss: 0.5664, Dice: 0.7685
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.5981, Dice: 0.6842
#     Local Epoch 2/2 - Loss: 0.5976, Dice: 0.6485
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.5593, Dice: 0.7363
#     Local Epoch 2/2 - Loss: 0.5421, Dice: 0.7568
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.5666, Dice: 0.7733
#     Local Epoch 2/2 - Loss: 0.5289, Dice: 0.7677
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.5448, Dice: 0.8084
#     Local Epoch 2/2 - Loss: 0.5211, Dice: 0.7664
# --- Federated Round 34/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.5365, Dice: 0.7276
#     Local Epoch 2/2 - Loss: 0.4781, Dice: 0.7714
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.5336, Dice: 0.7565
#     Local Epoch 2/2 - Loss: 0.5486, Dice: 0.7230
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.4930, Dice: 0.7890
#     Local Epoch 2/2 - Loss: 0.4694, Dice: 0.7716
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.5274, Dice: 0.7678
#     Local Epoch 2/2 - Loss: 0.4948, Dice: 0.8004
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.5032, Dice: 0.8032
#     Local Epoch 2/2 - Loss: 0.4807, Dice: 0.8026
# --- Federated Round 35/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.5394, Dice: 0.7485
#     Local Epoch 2/2 - Loss: 0.4987, Dice: 0.7050
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.5018, Dice: 0.7407
#     Local Epoch 2/2 - Loss: 0.5367, Dice: 0.6880
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.5060, Dice: 0.7262
#     Local Epoch 2/2 - Loss: 0.4260, Dice: 0.7859
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.4827, Dice: 0.7806
#     Local Epoch 2/2 - Loss: 0.4584, Dice: 0.8061
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.4575, Dice: 0.7788
#     Local Epoch 2/2 - Loss: 0.4495, Dice: 0.8109
#   Round 35: Avg Val Dice=0.7992, Avg Test Dice=0.8045, Avg Test IoU=0.6786
# --- Federated Round 36/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.4464, Dice: 0.7726
#     Local Epoch 2/2 - Loss: 0.4152, Dice: 0.7874
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.4232, Dice: 0.7948
#     Local Epoch 2/2 - Loss: 0.4807, Dice: 0.6926
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.4038, Dice: 0.8232
#     Local Epoch 2/2 - Loss: 0.4420, Dice: 0.7773
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.4391, Dice: 0.7773
#     Local Epoch 2/2 - Loss: 0.4400, Dice: 0.7555
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.4251, Dice: 0.7853
#     Local Epoch 2/2 - Loss: 0.4237, Dice: 0.8044
# --- Federated Round 37/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.4315, Dice: 0.7729
#     Local Epoch 2/2 - Loss: 0.4443, Dice: 0.7543
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.4197, Dice: 0.7750
#     Local Epoch 2/2 - Loss: 0.4103, Dice: 0.7772
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.4022, Dice: 0.8014
#     Local Epoch 2/2 - Loss: 0.4179, Dice: 0.7357
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.4116, Dice: 0.7933
#     Local Epoch 2/2 - Loss: 0.3950, Dice: 0.8083
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.3974, Dice: 0.8147
#     Local Epoch 2/2 - Loss: 0.3801, Dice: 0.8122
# --- Federated Round 38/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.3961, Dice: 0.7850
#     Local Epoch 2/2 - Loss: 0.3957, Dice: 0.7510
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.4164, Dice: 0.7736
#     Local Epoch 2/2 - Loss: 0.3669, Dice: 0.8034
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.3336, Dice: 0.8150
#     Local Epoch 2/2 - Loss: 0.3372, Dice: 0.8021
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.3857, Dice: 0.8088
#     Local Epoch 2/2 - Loss: 0.3729, Dice: 0.8028
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.3613, Dice: 0.8298
#     Local Epoch 2/2 - Loss: 0.3701, Dice: 0.7583
# --- Federated Round 39/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.4403, Dice: 0.6599
#     Local Epoch 2/2 - Loss: 0.3693, Dice: 0.7651
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.3762, Dice: 0.7902
#     Local Epoch 2/2 - Loss: 0.3633, Dice: 0.7730
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.3238, Dice: 0.8264
#     Local Epoch 2/2 - Loss: 0.3062, Dice: 0.8029
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.3635, Dice: 0.7881
#     Local Epoch 2/2 - Loss: 0.3703, Dice: 0.7752
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.3465, Dice: 0.8127
#     Local Epoch 2/2 - Loss: 0.3233, Dice: 0.8171
# --- Federated Round 40/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.3491, Dice: 0.7787
#     Local Epoch 2/2 - Loss: 0.3465, Dice: 0.7641
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.3379, Dice: 0.7925
#     Local Epoch 2/2 - Loss: 0.3497, Dice: 0.7536
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.3046, Dice: 0.8081
#     Local Epoch 2/2 - Loss: 0.2878, Dice: 0.8011
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.3239, Dice: 0.7857
#     Local Epoch 2/2 - Loss: 0.3143, Dice: 0.8094
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.3084, Dice: 0.8292
#     Local Epoch 2/2 - Loss: 0.2922, Dice: 0.8430
#   Round 40: Avg Val Dice=0.8273, Avg Test Dice=0.8209, Avg Test IoU=0.7024
# --- Federated Round 41/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.3361, Dice: 0.7809
#     Local Epoch 2/2 - Loss: 0.3756, Dice: 0.7346
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.3034, Dice: 0.8140
#     Local Epoch 2/2 - Loss: 0.3396, Dice: 0.7638
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.2901, Dice: 0.7960
#     Local Epoch 2/2 - Loss: 0.2754, Dice: 0.8044
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.3256, Dice: 0.8135
#     Local Epoch 2/2 - Loss: 0.3044, Dice: 0.8069
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.3111, Dice: 0.8206
#     Local Epoch 2/2 - Loss: 0.3121, Dice: 0.7866
# --- Federated Round 42/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.3047, Dice: 0.7860
#     Local Epoch 2/2 - Loss: 0.4012, Dice: 0.6869
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.3244, Dice: 0.7616
#     Local Epoch 2/2 - Loss: 0.2970, Dice: 0.7945
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.2879, Dice: 0.7706
#     Local Epoch 2/2 - Loss: 0.2840, Dice: 0.7777
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.3031, Dice: 0.8148
#     Local Epoch 2/2 - Loss: 0.3034, Dice: 0.8012
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.2657, Dice: 0.8356
#     Local Epoch 2/2 - Loss: 0.2669, Dice: 0.8342
# --- Federated Round 43/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.3519, Dice: 0.7465
#     Local Epoch 2/2 - Loss: 0.2977, Dice: 0.8015
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.3273, Dice: 0.7811
#     Local Epoch 2/2 - Loss: 0.3834, Dice: 0.7074
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.2654, Dice: 0.8174
#     Local Epoch 2/2 - Loss: 0.2287, Dice: 0.8444
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.2867, Dice: 0.8128
#     Local Epoch 2/2 - Loss: 0.2809, Dice: 0.8306
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.2472, Dice: 0.8316
#     Local Epoch 2/2 - Loss: 0.2371, Dice: 0.8488
# --- Federated Round 44/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.3291, Dice: 0.7418
#     Local Epoch 2/2 - Loss: 0.3013, Dice: 0.8081
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.2916, Dice: 0.7730
#     Local Epoch 2/2 - Loss: 0.3058, Dice: 0.7694
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.2071, Dice: 0.8370
#     Local Epoch 2/2 - Loss: 0.2099, Dice: 0.8295
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.2640, Dice: 0.8212
#     Local Epoch 2/2 - Loss: 0.2656, Dice: 0.8233
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.2416, Dice: 0.8384
#     Local Epoch 2/2 - Loss: 0.2534, Dice: 0.8015
# --- Federated Round 45/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.3365, Dice: 0.7398
#     Local Epoch 2/2 - Loss: 0.2744, Dice: 0.7937
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.2667, Dice: 0.8131
#     Local Epoch 2/2 - Loss: 0.2449, Dice: 0.8043
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.2272, Dice: 0.8188
#     Local Epoch 2/2 - Loss: 0.2241, Dice: 0.8393
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.2423, Dice: 0.8149
#     Local Epoch 2/2 - Loss: 0.2202, Dice: 0.8181
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.2414, Dice: 0.8378
#     Local Epoch 2/2 - Loss: 0.2368, Dice: 0.8063
#   Round 45: Avg Val Dice=0.8194, Avg Test Dice=0.8383, Avg Test IoU=0.7282
# --- Federated Round 46/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.2855, Dice: 0.7733
#     Local Epoch 2/2 - Loss: 0.2630, Dice: 0.8186
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.2501, Dice: 0.8146
#     Local Epoch 2/2 - Loss: 0.3068, Dice: 0.7227
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.2236, Dice: 0.8219
#     Local Epoch 2/2 - Loss: 0.2063, Dice: 0.8369
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.2586, Dice: 0.8193
#     Local Epoch 2/2 - Loss: 0.2215, Dice: 0.8256
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.2147, Dice: 0.8343
#     Local Epoch 2/2 - Loss: 0.2131, Dice: 0.8379
# --- Federated Round 47/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.2975, Dice: 0.7769
#     Local Epoch 2/2 - Loss: 0.2560, Dice: 0.7894
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.2626, Dice: 0.7690
#     Local Epoch 2/2 - Loss: 0.2645, Dice: 0.7792
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.2052, Dice: 0.8321
#     Local Epoch 2/2 - Loss: 0.1769, Dice: 0.8606
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.2126, Dice: 0.8510
#     Local Epoch 2/2 - Loss: 0.2453, Dice: 0.8066
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.2419, Dice: 0.8004
#     Local Epoch 2/2 - Loss: 0.2363, Dice: 0.8390
# --- Federated Round 48/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.2541, Dice: 0.7925
#     Local Epoch 2/2 - Loss: 0.2550, Dice: 0.7932
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.2927, Dice: 0.7657
#     Local Epoch 2/2 - Loss: 0.3252, Dice: 0.7042
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.2034, Dice: 0.8321
#     Local Epoch 2/2 - Loss: 0.2071, Dice: 0.8082
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.2395, Dice: 0.8175
#     Local Epoch 2/2 - Loss: 0.2076, Dice: 0.8380
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.2103, Dice: 0.8255
#     Local Epoch 2/2 - Loss: 0.2167, Dice: 0.8177
# --- Federated Round 49/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.2476, Dice: 0.7889
#     Local Epoch 2/2 - Loss: 0.2757, Dice: 0.7757
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.3238, Dice: 0.7141
#     Local Epoch 2/2 - Loss: 0.3363, Dice: 0.7008
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.2170, Dice: 0.8360
#     Local Epoch 2/2 - Loss: 0.2031, Dice: 0.8129
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.2355, Dice: 0.8446
#     Local Epoch 2/2 - Loss: 0.2024, Dice: 0.8196
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.2177, Dice: 0.8342
#     Local Epoch 2/2 - Loss: 0.2038, Dice: 0.8482
# --- Federated Round 50/50 ---
#   Client 0 training...
#     Local Epoch 1/2 - Loss: 0.2175, Dice: 0.8271
#     Local Epoch 2/2 - Loss: 0.2282, Dice: 0.8245
#   Client 1 training...
#     Local Epoch 1/2 - Loss: 0.2271, Dice: 0.8132
#     Local Epoch 2/2 - Loss: 0.2564, Dice: 0.7808
#   Client 2 training...
#     Local Epoch 1/2 - Loss: 0.1998, Dice: 0.8193
#     Local Epoch 2/2 - Loss: 0.2329, Dice: 0.8198
#   Client 3 training...
#     Local Epoch 1/2 - Loss: 0.2253, Dice: 0.8266
#     Local Epoch 2/2 - Loss: 0.2091, Dice: 0.8395
#   Client 4 training...
#     Local Epoch 1/2 - Loss: 0.2229, Dice: 0.8269
#     Local Epoch 2/2 - Loss: 0.1988, Dice: 0.8468
#   Round 50: Avg Val Dice=0.8263, Avg Test Dice=0.8443, Avg Test IoU=0.7389

# %%
plt.figure(figsize=(10,5))
plt.plot(results['round'], results['avg_test_dice'], label='Test Dice', marker='o')
plt.plot(results['round'], results['avg_test_iou'], label='Test IoU', marker='s')
plt.plot(results['round'], results['avg_val_dice'], label='Validation Dice', marker='^')
plt.xlabel('Federated Round')
plt.ylabel('Score')
plt.legend()
plt.title('Federated Learning Performance')
plt.grid(True)
plt.show()

torch.save(global_weights, '/content/drive/MyDrive/federated_lung_nodule_unetpp_effb3.pth')
print("Model saved!")
# Out:
# Model saved!

# %%
# ---------- New evaluation functions ----------
def compute_dice_from_probs(probs, target, threshold=0.5):
    preds = (probs > threshold).float()
    intersection = (preds * target).sum()
    return (2. * intersection + 1e-6) / (preds.sum() + target.sum() + 1e-6)

def compute_iou_from_probs(probs, target, threshold=0.5):
    preds = (probs > threshold).float()
    intersection = (preds * target).sum()
    union = preds.sum() + target.sum() - intersection
    return (intersection + 1e-6) / (union + 1e-6)

def postprocess_mask_light(mask, min_area=2, fill_holes=True):
    """Remove only tiny components (area < min_area) and fill holes."""
    if isinstance(mask, torch.Tensor):
        mask = mask.cpu().numpy()
    mask = mask.astype(np.uint8)
    # Remove small connected components
    num_labels, labels = cv2.connectedComponents(mask)
    cleaned = np.zeros_like(mask)
    for lab in range(1, num_labels):
        component = (labels == lab).astype(np.uint8)
        if np.sum(component) >= min_area:
            cleaned = np.logical_or(cleaned, component)
    cleaned = cleaned.astype(np.uint8)

    if fill_holes:
        contours, _ = cv2.findContours(cleaned, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        for cnt in contours:
            cv2.drawContours(cleaned, [cnt], 0, 1, thickness=cv2.FILLED)
    return cleaned

def find_best_threshold(weights, val_loader):
    """Find optimal threshold on validation set."""
    model = build_model().to(device)
    model.load_state_dict(weights)
    model.eval()
    best_dice = 0.0
    best_thresh = 0.5
    thresholds = np.arange(0.3, 0.7, 0.02)
    with torch.no_grad():
        for thresh in thresholds:
            dice_scores = []
            for imgs, masks in val_loader:
                imgs, masks = imgs.to(device), masks.to(device)
                logits = model(imgs)
                probs = torch.sigmoid(logits)
                dice = compute_dice_from_probs(probs, masks, threshold=thresh)
                dice_scores.append(dice.item())
            avg_dice = np.mean(dice_scores)
            if avg_dice > best_dice:
                best_dice = avg_dice
                best_thresh = thresh
    return best_thresh

def evaluate_with_optimizations(weights, dataloader, threshold=0.5, apply_postprocess=True):
    """Evaluate with threshold and light post-processing."""
    model = build_model().to(device)
    model.load_state_dict(weights)
    model.eval()
    dice_scores = []
    iou_scores = []
    with torch.no_grad():
        for imgs, masks in dataloader:
            imgs, masks = imgs.to(device), masks.to(device)
            logits = model(imgs)
            probs = torch.sigmoid(logits)
            preds = (probs > threshold).float().cpu().numpy()
            if apply_postprocess:
                preds_pp = np.zeros_like(preds)
                for i in range(preds.shape[0]):
                    preds_pp[i,0] = postprocess_mask_light(preds[i,0], min_area=2, fill_holes=True)
                preds = torch.tensor(preds_pp, device=device).float()
            else:
                preds = torch.tensor(preds, device=device).float()
            dice = compute_dice_from_pred(preds, masks)
            iou = compute_iou_from_pred(preds, masks)
            dice_scores.append(dice.item())
            iou_scores.append(iou.item())
    return np.mean(dice_scores), np.mean(iou_scores)

def compute_dice_from_pred(preds, target):
    intersection = (preds * target).sum()
    return (2. * intersection + 1e-6) / (preds.sum() + target.sum() + 1e-6)

def compute_iou_from_pred(preds, target):
    intersection = (preds * target).sum()
    union = preds.sum() + target.sum() - intersection
    return (intersection + 1e-6) / (union + 1e-6)

def evaluate_tta_enhanced(weights, dataloader, threshold=0.5, apply_postprocess=True):
    """TTA with 4 flip combinations + optional post-processing."""
    model = build_model().to(device)
    model.load_state_dict(weights)
    model.eval()
    dice_scores = []
    iou_scores = []

    flips = [(False, False), (True, False), (False, True), (True, True)]  # (hflip, vflip)

    with torch.no_grad():
        for imgs, masks in dataloader:
            imgs, masks = imgs.to(device), masks.to(device)
            probs_sum = torch.zeros_like(imgs, dtype=torch.float32)

            for hflip, vflip in flips:
                aug_imgs = imgs
                if hflip:
                    aug_imgs = torch.flip(aug_imgs, dims=[-1])
                if vflip:
                    aug_imgs = torch.flip(aug_imgs, dims=[-2])

                logits = model(aug_imgs)
                probs = torch.sigmoid(logits)

                if vflip:
                    probs = torch.flip(probs, dims=[-2])
                if hflip:
                    probs = torch.flip(probs, dims=[-1])
                probs_sum += probs

            probs_avg = probs_sum / len(flips)
            preds = (probs_avg > threshold).float().cpu().numpy()
            if apply_postprocess:
                preds_pp = np.zeros_like(preds)
                for i in range(preds.shape[0]):
                    preds_pp[i,0] = postprocess_mask_light(preds[i,0], min_area=2, fill_holes=True)
                preds = torch.tensor(preds_pp, device=device).float()
            else:
                preds = torch.tensor(preds, device=device).float()

            dice = compute_dice_from_pred(preds, masks)
            iou = compute_iou_from_pred(preds, masks)
            dice_scores.append(dice.item())
            iou_scores.append(iou.item())
    return np.mean(dice_scores), np.mean(iou_scores)

# %%
# Find best threshold on validation set (using client 0 as proxy)
best_thresh = find_best_threshold(global_weights, client_dataloaders[0]['val'])
print(f"Best threshold on client 0 validation: {best_thresh:.2f}")

# Evaluate all test clients with optimized settings
test_dices = []
test_ious = []
for i, client in enumerate(client_dataloaders):
    dice, iou = evaluate_with_optimizations(global_weights, client['test'],
                                            threshold=best_thresh, apply_postprocess=True)
    test_dices.append(dice)
    test_ious.append(iou)
    print(f"Client {i}: Dice={dice:.4f}, IoU={iou:.4f}")

avg_dice = np.mean(test_dices)
avg_iou = np.mean(test_ious)
print(f"\nAverage Test Dice = {avg_dice:.4f}, Average Test IoU = {avg_iou:.4f}")
# Out:
# Best threshold on client 0 validation: 0.44
# Client 0: Dice=0.8618, IoU=0.7576
# Client 1: Dice=0.8800, IoU=0.7864
# Client 2: Dice=0.8846, IoU=0.7932
# Client 3: Dice=0.7146, IoU=0.5671
# Client 4: Dice=0.8976, IoU=0.8149
#
# Average Test Dice = 0.8477, Average Test IoU = 0.7439

# %%
# Evaluate with TTA + optimizations on all test clients
tta_dices = []
tta_ious = []
for i, client in enumerate(client_dataloaders):
    dice, iou = evaluate_tta_enhanced(global_weights, client['test'],
                                      threshold=best_thresh, apply_postprocess=True)
    tta_dices.append(dice)
    tta_ious.append(iou)
    print(f"TTA Client {i}: Dice={dice:.4f}, IoU={iou:.4f}")

avg_tta_dice = np.mean(tta_dices)
avg_tta_iou = np.mean(tta_ious)
print(f"\nAverage TTA Dice = {avg_tta_dice:.4f}, Average TTA IoU = {avg_tta_iou:.4f}")
# Out:
# TTA Client 0: Dice=0.8474, IoU=0.7361
# TTA Client 1: Dice=0.8802, IoU=0.7864
# TTA Client 2: Dice=0.8943, IoU=0.8091
# TTA Client 3: Dice=0.6976, IoU=0.5493
# TTA Client 4: Dice=0.8895, IoU=0.8013
#
# Average TTA Dice = 0.8418, Average TTA IoU = 0.7364

# %%
import matplotlib.pyplot as plt

# Pick a random image
sample_idx = random.randint(0, len(ct_paths)-1)
ct_img = cv2.imread(ct_paths[sample_idx], cv2.IMREAD_GRAYSCALE)
mask_img = cv2.imread(mask_paths[sample_idx], cv2.IMREAD_GRAYSCALE)

ct_resized = cv2.resize(ct_img, (256, 256)) / 255.0
mask_resized = (cv2.resize(mask_img, (256, 256), interpolation=cv2.INTER_NEAREST) > 127).astype(np.float32)

data_dict = {'image': np.expand_dims(ct_resized, 0), 'mask': np.expand_dims(mask_resized, 0)}

fig, axes = plt.subplots(3, 4, figsize=(16, 12))
# Original
axes[0,0].imshow(ct_resized, cmap='gray')
axes[0,0].set_title('Original CT')
axes[1,0].imshow(mask_resized, cmap='jet', alpha=0.5)
axes[1,0].set_title('Ground Truth Mask')
axes[2,0].axis('off')

for i in range(1,4):
    augmented = train_transforms(data_dict.copy())
    aug_img = augmented['image'].squeeze().numpy()
    aug_mask = augmented['mask'].squeeze().numpy()

    axes[0,i].imshow(aug_img, cmap='gray')
    axes[0,i].set_title(f'Augmented CT {i}')
    axes[1,i].imshow(aug_mask, cmap='jet', alpha=0.5)
    axes[1,i].set_title(f'Aug Mask {i}')
    axes[2,i].imshow(aug_img, cmap='gray')
    axes[2,i].imshow(aug_mask, cmap='jet', alpha=0.4)
    axes[2,i].set_title('Overlay')

plt.tight_layout()
plt.show()

# %%
def visualize_predictions_optimized(weights, dataloader, num_samples=5, threshold=0.5):
    model = build_model().to(device)
    model.load_state_dict(weights)
    model.eval()

    data_iter = iter(dataloader)
    imgs, masks = next(data_iter)
    imgs, masks = imgs.to(device), masks.to(device)

    with torch.no_grad():
        logits = model(imgs)
        probs = torch.sigmoid(logits)
        preds = (probs > threshold).float().cpu().numpy()
        # Apply light post-processing
        preds_pp = np.zeros_like(preds)
        for i in range(preds.shape[0]):
            preds_pp[i,0] = postprocess_mask_light(preds[i,0], min_area=2, fill_holes=True)
        preds = preds_pp

    imgs_np = imgs.cpu().numpy().squeeze(1)
    masks_np = masks.cpu().numpy().squeeze(1)
    preds_np = preds.squeeze(1)

    fig, axes = plt.subplots(num_samples, 4, figsize=(12, 3*num_samples))
    if num_samples == 1:
        axes = axes[None, :]

    for i in range(num_samples):
        ct = imgs_np[i]
        gt = masks_np[i]
        pred = preds_np[i]

        dice = compute_dice_from_pred(torch.tensor(pred).float().unsqueeze(0).unsqueeze(0),
                                      torch.tensor(gt).float().unsqueeze(0).unsqueeze(0)).item()

        axes[i,0].imshow(ct, cmap='gray')
        axes[i,0].set_title(f'CT Image {i+1}')
        axes[i,0].axis('off')

        axes[i,1].imshow(gt, cmap='jet', alpha=0.6)
        axes[i,1].set_title('Ground Truth')
        axes[i,1].axis('off')

        axes[i,2].imshow(pred, cmap='jet', alpha=0.6)
        axes[i,2].set_title(f'Prediction (Dice={dice:.3f})')
        axes[i,2].axis('off')

        axes[i,3].imshow(ct, cmap='gray')
        axes[i,3].imshow(pred, cmap='jet', alpha=0.4)
        axes[i,3].set_title('Overlay')
        axes[i,3].axis('off')

    plt.tight_layout()
    plt.show()

# Use the best threshold found earlier
visualize_predictions_optimized(global_weights, client_dataloaders[0]['test'], num_samples=5, threshold=best_thresh)

# %%
client_dices = []
client_ious = []
client_names = []

for i, client in enumerate(client_dataloaders):
    # Use optimized evaluation
    dice, iou = evaluate_with_optimizations(global_weights, client['test'],
                                            threshold=best_thresh, apply_postprocess=True)
    client_dices.append(dice)
    client_ious.append(iou)
    client_names.append(f'Client {i}')

x = np.arange(len(client_names))
width = 0.35

fig, ax = plt.subplots(figsize=(10,5))
bar1 = ax.bar(x - width/2, client_dices, width, label='Dice', color='steelblue')
bar2 = ax.bar(x + width/2, client_ious, width, label='IoU', color='coral')

ax.set_ylabel('Score')
ax.set_title('Per‑Client Test Performance (Optimized Global Model)')
ax.set_xticks(x)
ax.set_xticklabels(client_names)
ax.legend()
ax.grid(axis='y', linestyle='--', alpha=0.7)

for bar in bar1+bar2:
    height = bar.get_height()
    ax.annotate(f'{height:.3f}',
                xy=(bar.get_x() + bar.get_width()/2, height),
                xytext=(0,3),
                textcoords="offset points",
                ha='center', va='bottom', fontsize=8)

plt.tight_layout()
plt.show()

# %%
nodule_areas = []
for mask_path in mask_paths:
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    mask = (mask > 127).astype(np.uint8)
    area = np.sum(mask)
    if area > 0:
        nodule_areas.append(area)

plt.figure(figsize=(8,5))
plt.hist(nodule_areas, bins=30, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('Nodule Area (pixels)')
plt.ylabel('Frequency')
plt.title('Distribution of Nodule Areas in Dataset')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %%
def overlay_contour(ct_img, pred_mask, gt_mask=None, ax=None):
    if ax is None:
        fig, ax = plt.subplots()
    ax.imshow(ct_img, cmap='gray')
    if gt_mask is not None:
        contours, _ = cv2.findContours(gt_mask.astype(np.uint8), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        for c in contours:
            ax.plot(c[:,0,0], c[:,0,1], 'g-', linewidth=2, label='Ground Truth')
    if pred_mask is not None:
        contours, _ = cv2.findContours(pred_mask.astype(np.uint8), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        for c in contours:
            ax.plot(c[:,0,0], c[:,0,1], 'r--', linewidth=2, label='Prediction')
    ax.legend()
    ax.axis('off')

example_idx = clients[0]['test'][0]
ct_ex = cv2.imread(ct_paths[example_idx], cv2.IMREAD_GRAYSCALE)
ct_ex = cv2.resize(ct_ex, (256,256)) / 255.0
gt_ex = (cv2.resize(cv2.imread(mask_paths[example_idx], cv2.IMREAD_GRAYSCALE), (256,256), interpolation=cv2.INTER_NEAREST) > 127).astype(np.float32)

model = build_model().to(device)
model.load_state_dict(global_weights)
model.eval()
with torch.no_grad():
    input_tensor = torch.tensor(ct_ex[None,None,...], dtype=torch.float32).to(device)
    pred_prob = torch.sigmoid(model(input_tensor)).cpu().numpy().squeeze()
pred_mask = (pred_prob > best_thresh).astype(np.float32)
pred_mask = postprocess_mask_light(pred_mask, min_area=2, fill_holes=True)

plt.figure(figsize=(6,6))
overlay_contour(ct_ex, pred_mask, gt_ex)
plt.title(f'Nodule Boundary: GT (green) vs Prediction (red), threshold={best_thresh:.2f}')
plt.show()
